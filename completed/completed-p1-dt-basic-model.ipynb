# %% [markdown]
# <a href="https://www.kaggle.com/code/funxexcel/completed-p1-dt-basic-model?scriptVersionId=108149688" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# # Part 1 : Decision Trees Basic Model

# %% [markdown]
# ## Import Libraries

# %%
import numpy as np 
import pandas as pd

# %% [markdown]
# ## Import Data

# %%
import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# %%
data = pd.read_csv('/kaggle/input/credit-card-approval-clean-data/clean_dataset.csv')

# %% [markdown]
# ### Describe Data

# %%
data.head()

# %%
data.info()

# %%
data.columns.tolist()

# %% [markdown]
# ## Partition Data into X and y

# %%
y = data['Approved']
X = data.drop('Approved', axis = 1)

# %%
# Check y
y.head(10)

# %%
# Check X
X.head(10)

# %% [markdown]
# ## Decision Tree

# %% [markdown]
# ### 1/ Import Library

# %%
# Classification
from sklearn.tree import DecisionTreeClassifier

# %%
DecisionTreeClassifier

# %% [markdown]
# ### 2/ Initiate an Instance

# %%
dt_model = DecisionTreeClassifier(random_state = 42)

# %% [markdown]
# ### 3/ Fit Model

# %%
dt_model.fit(X,y)

# %% [markdown]
# ### Pre Process Data
# - Only Dummy Variable Creation

# %%
X = pd.get_dummies(X)
X.head()

# %%
X.info()

# %% [markdown]
# ### 3/ Fit Model (Again)

# %%
dt_model.fit(X,y)

# %%
dt_model.get_depth()

# %% [markdown]
# ### 4/ Make Predictions

# %%
y_predicted = dt_model.predict(X)
y_predicted

# %% [markdown]
# ### 5/ Check Performance

# %% [markdown]
# #### Method 1
# - score
# - inputs : X and y

# %%
dt_model.score(X, y)

# %% [markdown]
# #### Method 2
# - Import from Metrics
# - Call an Instance
# - Use Actual vs Predicted y to get Performacne

# %%
from sklearn.metrics import classification_report

# %%
print(classification_report(y, y_predicted))

# %% [markdown]
# # Too good to be true?
